# %% [markdown]
# # 01 Data Overview
# Load and validate the real CSV from `data/raw/water_quality.csv`. No sample measurements are generated.

# %%
from pathlib import Path
import os

PROJECT_ROOT = Path("/Users/jakobsmacncheese/Desktop/ISU/VRO-Project")
os.chdir(PROJECT_ROOT)

print("Working directory:", Path.cwd())





from src.data_preprocessing import load_data, validate_data
df = load_data("data/raw/water_quality.csv")
validation = validate_data(df)
validation
# Out:
# Working directory: /Users/jakobsmacncheese/Desktop/ISU/VRO-Project
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118286 entries, 0 to 118285
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            118286 non-null  int64
#  1   created_date  118286 non-null  datetime64[ns]
#  2   water_pH      118286 non-null  float64
#  3   TDS           118286 non-null  int64
#  4   water_temp    118286 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 4.5 MB
# None
# {'missing_values': {'id': 0,
#   'created_date': 0,
#   'water_pH': 0,
#   'TDS': 0,
#   'water_temp': 0},
#  'duplicate_rows': 0,
#  'duplicate_ids': 0,
#  'invalid_dates': 0,
#  'invalid_numeric_values': 0,
#  'is_chronologically_sorted': True,
#  'outlier_candidates': {'water_pH_outlier_candidate': 0,
#   'TDS_outlier_candidate': 0,
#   'water_temp_outlier_candidate': 0},
# ...

# %%
print(Path.cwd())
# Out:
# /Users/jakobsmacncheese/Desktop/ISU/VRO-Project
